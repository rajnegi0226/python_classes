# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/Vivek negi/Downloads/Cleaned_Car_data.csv")

# %%
x = pd.read_csv("C:/Users/Vivek negi/Downloads/Cleaned_Car_data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                    name   company  year   Price  kms_driven  \
# 0           0     Hyundai Santro Xing   Hyundai  2007   80000       45000
# 1           1     Mahindra Jeep CL550  Mahindra  2006  425000          40
# 2           2       Hyundai Grand i10   Hyundai  2014  325000       28000
# 3           3  Ford EcoSport Titanium      Ford  2014  575000       36000
# 4           4               Ford Figo      Ford  2012  175000       41000
#
#   fuel_type
# 0    Petrol
# 1    Diesel
# 2    Petrol
# 3    Diesel
# 4    Diesel

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'name', 'company', 'year', 'Price', 'kms_driven',
#        'fuel_type'],
#       dtype='object')

# %%
df.columns =['Unnamed: 0', 'name', 'company', 'year', 'Price', 'kms_driven','fuel_type']

# %%
df.head()
# Out:
#    Unnamed: 0                    name   company  year   Price  kms_driven  \
# 0           0     Hyundai Santro Xing   Hyundai  2007   80000       45000
# 1           1     Mahindra Jeep CL550  Mahindra  2006  425000          40
# 2           2       Hyundai Grand i10   Hyundai  2014  325000       28000
# 3           3  Ford EcoSport Titanium      Ford  2014  575000       36000
# 4           4               Ford Figo      Ford  2012  175000       41000
#
#   fuel_type
# 0    Petrol
# 1    Diesel
# 2    Petrol
# 3    Diesel
# 4    Diesel

# %%
df.loc[1,'name'] = "Hyundai"

# %%
df.head()
# Out:
#    Unnamed: 0                    name   company  year   Price  kms_driven  \
# 0           0     Hyundai Santro Xing   Hyundai  2007   80000       45000
# 1           1                 Hyundai  Mahindra  2006  425000          40
# 2           2       Hyundai Grand i10   Hyundai  2014  325000       28000
# 3           3  Ford EcoSport Titanium      Ford  2014  575000       36000
# 4           4               Ford Figo      Ford  2012  175000       41000
#
#   fuel_type
# 0    Petrol
# 1    Diesel
# 2    Petrol
# 3    Diesel
# 4    Diesel

# %%
df.loc[(df.index[0:3]),'name'] = "Hyundai"

# %%
df.head()
# Out:
#    Unnamed: 0                    name   company  year   Price  kms_driven  \
# 0           0                 Hyundai   Hyundai  2007   80000       45000
# 1           1                 Hyundai  Mahindra  2006  425000          40
# 2           2                 Hyundai   Hyundai  2014  325000       28000
# 3           3  Ford EcoSport Titanium      Ford  2014  575000       36000
# 4           4               Ford Figo      Ford  2012  175000       41000
#
#   fuel_type
# 0    Petrol
# 1    Diesel
# 2    Petrol
# 3    Diesel
# 4    Diesel

# %%
df.loc[(df['year']>2014)]
# Out:
#      Unnamed: 0                    name   company  year    Price  kms_driven  \
# 6             6  Ford EcoSport Ambiente      Ford  2016   830000       24530
# 7             7      Maruti Suzuki Alto    Maruti  2015   250000       60000
# 9             9  Maruti Suzuki Stingray    Maruti  2015   315000       30000
# 11           11    Mahindra Scorpio SLE  Mahindra  2015   320000       48660
# 14           14                 Audi A8      Audi  2017  1000000        4000
# ..          ...                     ...       ...   ...      ...         ...
# 802         802     Maruti Suzuki Dzire    Maruti  2016   325000      150000
# 803         803       Hyundai Elite i20   Hyundai  2018   510000        2100
# 804         804           Honda City VX     Honda  2016   860000       95000
# 805         805     Maruti Suzuki Dzire    Maruti  2016   450000        2500
# 814         814            Tata Zest XM      Tata  2018   260000       27000
#
#     fuel_type
# 6      Diesel
# ...

# %%
year2018 = df.loc[(df['year']>=2018)]

# %%
year2018
# Out:
#      Unnamed: 0                       name     company  year    Price  \
# 34           34           Renault Lodgy 85     Renault  2018   689999
# 82           82  Volkswagen Vento Highline  Volkswagen  2019  1200000
# 124         124         Maruti Suzuki Alto      Maruti  2018   200000
# 144         144          Hyundai Elite i20     Hyundai  2018   599999
# 150         150         Maruti Suzuki Alto      Maruti  2018   310000
# 206         206           Mahindra Jeep MM    Mahindra  2019   390000
# 211         211        Mahindra Jeep CL550    Mahindra  2019   379000
# 213         213        Mahindra Jeep CL550    Mahindra  2018   385000
# 266         266           Renault Kwid RXT     Renault  2018   325000
# 268         268           Renault Kwid 1.0     Renault  2018   349999
# 269         269           Renault Lodgy 85     Renault  2018   689999
# 290         290        Maruti Suzuki Swift      Maruti  2019   610000
# ...

# %%
df.head()
# Out:
#    Unnamed: 0                    name   company  year   Price  kms_driven  \
# 0           0                 Hyundai   Hyundai  2007   80000       45000
# 1           1                 Hyundai  Mahindra  2006  425000          40
# 2           2                 Hyundai   Hyundai  2014  325000       28000
# 3           3  Ford EcoSport Titanium      Ford  2014  575000       36000
# 4           4               Ford Figo      Ford  2012  175000       41000
#
#   fuel_type
# 0    Petrol
# 1    Diesel
# 2    Petrol
# 3    Diesel
# 4    Diesel

# %%
x1=df.loc[(df['year']>2018) & (df['kms_driven']>1000)]

# %%
x1
# Out:
#      Unnamed: 0                       name     company  year    Price  \
# 82           82  Volkswagen Vento Highline  Volkswagen  2019  1200000
# 517         517          Hyundai Verna 1.6     Hyundai  2019   900000
# 539         539         Maruti Suzuki Alto      Maruti  2019   265000
# 769         769         Mahindra KUV100 K8    Mahindra  2019   560000
# 771         771          Ford Endeavor 4x4        Ford  2019  2900000
# 776         776         Maruti Suzuki Alto      Maruti  2019   400000
# 779         779         Maruti Suzuki Alto      Maruti  2019   425000
#
#      kms_driven fuel_type
# 82         3600    Diesel
# 517        2000    Petrol
# 539        9800    Petrol
# 769        2875    Petrol
# 771        9000    Diesel
# 776        1500    Petrol
# 779        1625    Petrol

# %%
x2=df.loc[(df['year']>2000)&(df['Price']>10000)&(df['fuel_type']=='Petrol')]

# %%
x2
# Out:
#      Unnamed: 0                  name   company  year   Price  kms_driven  \
# 0             0               Hyundai   Hyundai  2007   80000       45000
# 2             2               Hyundai   Hyundai  2014  325000       28000
# 5             5           Hyundai Eon   Hyundai  2013  190000       25000
# 7             7    Maruti Suzuki Alto    Maruti  2015  250000       60000
# 8             8   Skoda Fabia Classic     Skoda  2010  182000       60000
# ..          ...                   ...       ...   ...     ...         ...
# 807         807       Mercedes Benz C  Mercedes  2006  500001       15000
# 808         808    Maruti Suzuki Alto    Maruti  2005   95000       65000
# 810         810           Skoda Fabia     Skoda  2009  110000       45000
# 811         811    Maruti Suzuki Ritz    Maruti  2011  270000       50000
# 813         813  Toyota Corolla Altis    Toyota  2009  300000      132000
#
#     fuel_type
# 0      Petrol
# 2      Petrol
# 5      Petrol
# 7      Petrol
# ...

# %%
x3=df.loc[(df['year']>2000)|(df['Price']>900000)]

# %%
x3
# Out:
#      Unnamed: 0                    name   company  year   Price  kms_driven  \
# 0             0                 Hyundai   Hyundai  2007   80000       45000
# 1             1                 Hyundai  Mahindra  2006  425000          40
# 2             2                 Hyundai   Hyundai  2014  325000       28000
# 3             3  Ford EcoSport Titanium      Ford  2014  575000       36000
# 4             4               Ford Figo      Ford  2012  175000       41000
# ..          ...                     ...       ...   ...     ...         ...
# 811         811      Maruti Suzuki Ritz    Maruti  2011  270000       50000
# 812         812          Tata Indica V2      Tata  2009  110000       30000
# 813         813    Toyota Corolla Altis    Toyota  2009  300000      132000
# 814         814            Tata Zest XM      Tata  2018  260000       27000
# 815         815      Mahindra Quanto C8  Mahindra  2013  390000       40000
#
#     fuel_type
# 0      Petrol
# 1      Diesel
# ...

# %%
x3=df.loc[(df['year']>2000)&(df['Price']>10000)&(df['fuel_type']=='Diesel')]

# %%
x3
# Out:
#      Unnamed: 0                    name   company  year   Price  kms_driven  \
# 1             1                 Hyundai  Mahindra  2006  425000          40
# 3             3  Ford EcoSport Titanium      Ford  2014  575000       36000
# 4             4               Ford Figo      Ford  2012  175000       41000
# 6             6  Ford EcoSport Ambiente      Ford  2016  830000       24530
# 11           11    Mahindra Scorpio SLE  Mahindra  2015  320000       48660
# ..          ...                     ...       ...   ...     ...         ...
# 805         805     Maruti Suzuki Dzire    Maruti  2016  450000        2500
# 809         809     Maruti Suzuki Swift    Maruti  2009  250000       51000
# 812         812          Tata Indica V2      Tata  2009  110000       30000
# 814         814            Tata Zest XM      Tata  2018  260000       27000
# 815         815      Mahindra Quanto C8  Mahindra  2013  390000       40000
#
#     fuel_type
# 1      Diesel
# 3      Diesel
# ...

# %%
df.loc[(df['year'].between(2015,2018))&(df['kms_driven']>40)&(df["fuel_type"]=='Petrol')]
# Out:
#      Unnamed: 0                          name     company  year    Price  \
# 7             7            Maruti Suzuki Alto      Maruti  2015   250000
# 9             9        Maruti Suzuki Stingray      Maruti  2015   315000
# 14           14                       Audi A8        Audi  2017  1000000
# 20           20            Maruti Suzuki Alto      Maruti  2015    75000
# 24           24            Maruti Suzuki Alto      Maruti  2017   190000
# ..          ...                           ...         ...   ...      ...
# 778         778            Maruti Suzuki Alto      Maruti  2016   250000
# 780         780  Volkswagen Polo Highline1.2L  Volkswagen  2017   525000
# 787         787                   Hyundai Eon     Hyundai  2018   260000
# 803         803             Hyundai Elite i20     Hyundai  2018   510000
# 804         804                 Honda City VX       Honda  2016   860000
#
#      kms_driven fuel_type
# 7         60000    Petrol
# 9         30000    Petrol
# ...

# %%
df.loc[(df['year'].between(2015,2018))&(df['company']=='Tata')&(df['kms_driven']>2000)&(df["fuel_type"]=='Diesel')].count()
# Out:
# Unnamed: 0    25
# name          25
# company       25
# year          25
# Price         25
# kms_driven    25
# fuel_type     25
# dtype: int64

# %%
x.drop([8,9],axis=0,inplace=True)

# %%
x
# Out:
#      Unnamed: 0                    name   company  year   Price  kms_driven  \
# 0             0     Hyundai Santro Xing   Hyundai  2007   80000       45000
# 1             1     Mahindra Jeep CL550  Mahindra  2006  425000          40
# 2             2       Hyundai Grand i10   Hyundai  2014  325000       28000
# 3             3  Ford EcoSport Titanium      Ford  2014  575000       36000
# 4             4               Ford Figo      Ford  2012  175000       41000
# ..          ...                     ...       ...   ...     ...         ...
# 811         811      Maruti Suzuki Ritz    Maruti  2011  270000       50000
# 812         812          Tata Indica V2      Tata  2009  110000       30000
# 813         813    Toyota Corolla Altis    Toyota  2009  300000      132000
# 814         814            Tata Zest XM      Tata  2018  260000       27000
# 815         815      Mahindra Quanto C8  Mahindra  2013  390000       40000
#
#     fuel_type
# 0      Petrol
# 1      Diesel
# ...

# %%
x.reset_index()
# Out:
#      index  Unnamed: 0                    name   company  year   Price  \
# 0        0           0     Hyundai Santro Xing   Hyundai  2007   80000
# 1        1           1     Mahindra Jeep CL550  Mahindra  2006  425000
# 2        2           2       Hyundai Grand i10   Hyundai  2014  325000
# 3        3           3  Ford EcoSport Titanium      Ford  2014  575000
# 4        4           4               Ford Figo      Ford  2012  175000
# ..     ...         ...                     ...       ...   ...     ...
# 809    811         811      Maruti Suzuki Ritz    Maruti  2011  270000
# 810    812         812          Tata Indica V2      Tata  2009  110000
# 811    813         813    Toyota Corolla Altis    Toyota  2009  300000
# 812    814         814            Tata Zest XM      Tata  2018  260000
# 813    815         815      Mahindra Quanto C8  Mahindra  2013  390000
#
#      kms_driven fuel_type
# 0         45000    Petrol
# 1            40    Diesel
# 2         28000    Petrol
# ...

# %%
#x.reset_index(drop=True)

# %%
df1=pd.read_excel('c:/Users/Vivek negi/OneDrive/Desktop/Book1.xlsx')

# %%
df1
# Out:
#     S.no.                    name   company  year   Price  kms_driven  \
# 0       1     Hyundai Santro Xing  Mahindra  2013   80000       18000
# 1       2     Mahindra Jeep CL550   Hyundai  2016  425000       35000
# 2       3       Hyundai Grand i10  Mahindra  2015  325000       13349
# 3       4  Ford EcoSport Titanium      Audi  2010  575000       29000
# 4       5               Ford Figo      Audi  2015  175000       44000
# 5       6             Hyundai Eon  Mahindra  2014  190000       29000
# 6       7  Ford EcoSport Ambiente    Maruti  2015  830000       42000
# 7       8      Maruti Suzuki Alto  Mahindra  2007  250000       14000
# 8       9     Skoda Fabia Classic  Mahindra  2006  182000       49000
# 9      10  Maruti Suzuki Stingray    Maruti  2017  315000       42000
# 10     11       Hyundai Elite i20   Hyundai  2014  415000       36200
#
#    fuel_type
# 0     Petrol
# 1     Diesel
# 2     Petrol
# 3     Petrol
# 4     Diesel
# 5     Petrol
# 6     Diesel
# ...

# %%
df
# Out:
#      Unnamed: 0                    name   company  year   Price  kms_driven  \
# 0             0     Hyundai Santro Xing   Hyundai  2007   80000       45000
# 1             1     Mahindra Jeep CL550  Mahindra  2006  425000          40
# 2             2       Hyundai Grand i10   Hyundai  2014  325000       28000
# 3             3  Ford EcoSport Titanium      Ford  2014  575000       36000
# 4             4               Ford Figo      Ford  2012  175000       41000
# ..          ...                     ...       ...   ...     ...         ...
# 811         811      Maruti Suzuki Ritz    Maruti  2011  270000       50000
# 812         812          Tata Indica V2      Tata  2009  110000       30000
# 813         813    Toyota Corolla Altis    Toyota  2009  300000      132000
# 814         814            Tata Zest XM      Tata  2018  260000       27000
# 815         815      Mahindra Quanto C8  Mahindra  2013  390000       40000
#
#     fuel_type
# 0      Petrol
# 1      Diesel
# ...

# %%
df = pd.read_csv("C:/Users/Vivek negi/Downloads/Cleaned_Car_data.csv")

# %%
df2=[df1,df]

# %%
df2 = pd.concat(df2)

# %%
df2.shape
# Out:
# (827, 8)

# %%
df2
# Out:
#      S.no.                    name   company  year   Price  kms_driven  \
# 0      1.0     Hyundai Santro Xing  Mahindra  2013   80000       18000
# 1      2.0     Mahindra Jeep CL550   Hyundai  2016  425000       35000
# 2      3.0       Hyundai Grand i10  Mahindra  2015  325000       13349
# 3      4.0  Ford EcoSport Titanium      Audi  2010  575000       29000
# 4      5.0               Ford Figo      Audi  2015  175000       44000
# ..     ...                     ...       ...   ...     ...         ...
# 811    NaN      Maruti Suzuki Ritz    Maruti  2011  270000       50000
# 812    NaN          Tata Indica V2      Tata  2009  110000       30000
# 813    NaN    Toyota Corolla Altis    Toyota  2009  300000      132000
# 814    NaN            Tata Zest XM      Tata  2018  260000       27000
# 815    NaN      Mahindra Quanto C8  Mahindra  2013  390000       40000
#
#     fuel_type  Unnamed: 0
# 0      Petrol         NaN
# 1      Diesel         NaN
# 2      Petrol         NaN
# ...

# %%
df1.shape
# Out:
# (11, 7)

# %%
df1.head()
# Out:
#    S.no.                    name   company  year   Price  kms_driven fuel_type
# 0      1     Hyundai Santro Xing  Mahindra  2013   80000       18000    Petrol
# 1      2     Mahindra Jeep CL550   Hyundai  2016  425000       35000    Diesel
# 2      3       Hyundai Grand i10  Mahindra  2015  325000       13349    Petrol
# 3      4  Ford EcoSport Titanium      Audi  2010  575000       29000    Petrol
# 4      5               Ford Figo      Audi  2015  175000       44000    Diesel

# %%
df1.columns
# Out:
# Index(['S.no.', 'name', 'company', 'year', 'Price', 'kms_driven', 'fuel_type'], dtype='object')

# %%
df2
# Out:
#      S.no.                    name   company  year   Price  kms_driven  \
# 0      1.0     Hyundai Santro Xing  Mahindra  2013   80000       18000
# 1      2.0     Mahindra Jeep CL550   Hyundai  2016  425000       35000
# 2      3.0       Hyundai Grand i10  Mahindra  2015  325000       13349
# 3      4.0  Ford EcoSport Titanium      Audi  2010  575000       29000
# 4      5.0               Ford Figo      Audi  2015  175000       44000
# ..     ...                     ...       ...   ...     ...         ...
# 811    NaN      Maruti Suzuki Ritz    Maruti  2011  270000       50000
# 812    NaN          Tata Indica V2      Tata  2009  110000       30000
# 813    NaN    Toyota Corolla Altis    Toyota  2009  300000      132000
# 814    NaN            Tata Zest XM      Tata  2018  260000       27000
# 815    NaN      Mahindra Quanto C8  Mahindra  2013  390000       40000
#
#     fuel_type  Unnamed: 0
# 0      Petrol         NaN
# 1      Diesel         NaN
# 2      Petrol         NaN
# ...
