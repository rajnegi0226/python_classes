# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv("C:/Users/Vivek negi/Downloads/Cleaned_Car_data.csv")

# %%
df1=pd.read_excel('c:/Users/Vivek negi/OneDrive/Desktop/Book1.xlsx')

# %%
df2 = pd.concat([df1,df])

# %%
df2.shape
# Out:
# (827, 8)

# %%
df2 = pd.concat([df,df1],keys=['x','y'])

# %%
df2
# Out:
#       Unnamed: 0                    name   company  year   Price  kms_driven  \
# x 0          0.0     Hyundai Santro Xing   Hyundai  2007   80000       45000
#   1          1.0     Mahindra Jeep CL550  Mahindra  2006  425000          40
#   2          2.0       Hyundai Grand i10   Hyundai  2014  325000       28000
#   3          3.0  Ford EcoSport Titanium      Ford  2014  575000       36000
#   4          4.0               Ford Figo      Ford  2012  175000       41000
# ...          ...                     ...       ...   ...     ...         ...
# y 6          NaN  Ford EcoSport Ambiente    Maruti  2015  830000       42000
#   7          NaN      Maruti Suzuki Alto  Mahindra  2007  250000       14000
#   8          NaN     Skoda Fabia Classic  Mahindra  2006  182000       49000
#   9          NaN  Maruti Suzuki Stingray    Maruti  2017  315000       42000
#   10         NaN       Hyundai Elite i20   Hyundai  2014  415000       36200
#
#      fuel_type  S.no.
# ...

# %%
df2.head()
# Out:
#      Unnamed: 0                    name   company  year   Price  kms_driven  \
# x 0         0.0     Hyundai Santro Xing   Hyundai  2007   80000       45000
#   1         1.0     Mahindra Jeep CL550  Mahindra  2006  425000          40
#   2         2.0       Hyundai Grand i10   Hyundai  2014  325000       28000
#   3         3.0  Ford EcoSport Titanium      Ford  2014  575000       36000
#   4         4.0               Ford Figo      Ford  2012  175000       41000
#
#     fuel_type  S.no.
# x 0    Petrol    NaN
#   1    Diesel    NaN
#   2    Petrol    NaN
#   3    Diesel    NaN
#   4    Diesel    NaN

# %%
df2.size
# Out:
# 6616

# %%
df.groupby('fuel_type').count()
# Out:
#            Unnamed: 0  name  company  year  Price  kms_driven
# fuel_type
# Diesel            386   386      386   386    386         386
# LPG                 2     2        2     2      2           2
# Petrol            428   428      428   428    428         428

# %%
df.groupby('fuel_type').mean()
# Out:
#            Unnamed: 0         year          Price     kms_driven
# fuel_type
# Diesel     402.974093  2013.253886  509849.386010   55650.984456
# LPG        521.500000  2012.500000  205000.000000  115000.000000
# Petrol     411.049065  2011.714953  324181.567757   37498.957944

# %%
df1.groupby('company').mean()
# Out:
#           S.no.    year     Price  kms_driven
# company
# Audi        4.5  2012.5  375000.0     36500.0
# Hyundai     6.5  2015.0  420000.0     35600.0
# Mahindra    5.4  2011.0  205400.0     24669.8
# Maruti      8.5  2016.0  572500.0     42000.0

# %%
df.groupby('year').count()
# Out:
#       Unnamed: 0  name  company  Price  kms_driven  fuel_type
# year
# 1995           2     2        2      2           2          2
# 2000           7     7        7      7           7          7
# 2001           5     5        5      5           5          5
# 2002           4     4        4      4           4          4
# 2003          13    13       13     13          13         13
# 2004          12    12       12     12          12         12
# 2005          13    13       13     13          13         13
# 2006          22    22       22     22          22         22
# 2007          19    19       19     19          19         19
# 2008          16    16       16     16          16         16
# 2009          54    54       54     54          54         54
# 2010          43    43       43     43          43         43
# 2011          59    59       59     59          59         59
# 2012          75    75       75     75          75         75
# ...

# %%
x =df.loc[(df['company']=='Tata') & (df['kms_driven']>0)]

# %%
df
# Out:
#      Unnamed: 0                    name   company  year   Price  kms_driven  \
# 0             0     Hyundai Santro Xing   Hyundai  2007   80000       45000
# 1             1     Mahindra Jeep CL550  Mahindra  2006  425000          40
# 2             2       Hyundai Grand i10   Hyundai  2014  325000       28000
# 3             3  Ford EcoSport Titanium      Ford  2014  575000       36000
# 4             4               Ford Figo      Ford  2012  175000       41000
# ..          ...                     ...       ...   ...     ...         ...
# 811         811      Maruti Suzuki Ritz    Maruti  2011  270000       50000
# 812         812          Tata Indica V2      Tata  2009  110000       30000
# 813         813    Toyota Corolla Altis    Toyota  2009  300000      132000
# 814         814            Tata Zest XM      Tata  2018  260000       27000
# 815         815      Mahindra Quanto C8  Mahindra  2013  390000       40000
#
#     fuel_type
# 0      Petrol
# 1      Diesel
# ...

# %%
x
# Out:
#      Unnamed: 0             name company  year   Price  kms_driven fuel_type
# 60           60  Tata Indigo eCS    Tata  2017  200000      130000    Diesel
# 62           62  Tata Indigo eCS    Tata  2017  200000      130000    Diesel
# 132         132   Tata Indica V2    Tata  2006   90000       20000    Petrol
# 163         163   Tata Indigo CS    Tata  2011   85000       11400    Diesel
# 177         177  Tata Indigo eCS    Tata  2016  320000      175430    Diesel
# ..          ...              ...     ...   ...     ...         ...       ...
# 793         793  Tata Indica eV2    Tata  2016   50500       91200    Diesel
# 795         795     Tata Zest XE    Tata  2017  290000      120000    Diesel
# 797         797  Tata Indigo eCS    Tata  2016  160000      104000    Diesel
# 812         812   Tata Indica V2    Tata  2009  110000       30000    Diesel
# 814         814     Tata Zest XM    Tata  2018  260000       27000    Diesel
#
# [64 rows x 7 columns]

# %%
df.isnull()
# Out:
#      Unnamed: 0   name  company   year  Price  kms_driven  fuel_type
# 0         False  False    False  False  False       False      False
# 1         False  False    False  False  False       False      False
# 2         False  False    False  False  False       False      False
# 3         False  False    False  False  False       False      False
# 4         False  False    False  False  False       False      False
# ..          ...    ...      ...    ...    ...         ...        ...
# 811       False  False    False  False  False       False      False
# 812       False  False    False  False  False       False      False
# 813       False  False    False  False  False       False      False
# 814       False  False    False  False  False       False      False
# 815       False  False    False  False  False       False      False
#
# [816 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# name          0
# company       0
# year          0
# Price         0
# kms_driven    0
# fuel_type     0
# dtype: int64

# %%
len(df.columns)
# Out:
# 7

# %%
len(df)
# Out:
# 816

# %%
df['Price'].max()
# Out:
# 8500003

# %%
df['Price'].describe()
# Out:
# count    8.160000e+02
# mean     4.117176e+05
# std      4.751844e+05
# min      3.000000e+04
# 25%      1.750000e+05
# 50%      2.999990e+05
# 75%      4.912500e+05
# max      8.500003e+06
# Name: Price, dtype: float64

# %%
df['Price'].median()
# Out:
# 299999.0

# %%
dollarprice=df['Price']/80

# %%
df6=df.assign(Priceindollar=dollarprice)

# %%
df.head()
# Out:
#    Unnamed: 0                    name   company  year   Price  kms_driven  \
# 0           0     Hyundai Santro Xing   Hyundai  2007   80000       45000
# 1           1     Mahindra Jeep CL550  Mahindra  2006  425000          40
# 2           2       Hyundai Grand i10   Hyundai  2014  325000       28000
# 3           3  Ford EcoSport Titanium      Ford  2014  575000       36000
# 4           4               Ford Figo      Ford  2012  175000       41000
#
#   fuel_type
# 0    Petrol
# 1    Diesel
# 2    Petrol
# 3    Diesel
# 4    Diesel

# %%
df6.head()
# Out:
#    Unnamed: 0                    name   company  year   Price  kms_driven  \
# 0           0     Hyundai Santro Xing   Hyundai  2007   80000       45000
# 1           1     Mahindra Jeep CL550  Mahindra  2006  425000          40
# 2           2       Hyundai Grand i10   Hyundai  2014  325000       28000
# 3           3  Ford EcoSport Titanium      Ford  2014  575000       36000
# 4           4               Ford Figo      Ford  2012  175000       41000
#
#   fuel_type  Priceindollar
# 0    Petrol         1000.0
# 1    Diesel         5312.5
# 2    Petrol         4062.5
# 3    Diesel         7187.5
# 4    Diesel         2187.5
