# %%
import mysql.connector

# %%
cnx = mysql.connector.connect(user='root',password='RAJnegi7455@$#',
                              host='127.0.0.1',
                              database='hr_data')
cursor = cnx.cursor()

# showing existing table
cursor.execute('SHOW TABLES')

for x in cursor:
    print(x)
# Out:
# ('hrskill',)

# %%
import pandas as pd 
import numpy as np

# %%
df=pd.read_sql_query('''SELECT *FROM hrskill''',con=cnx)

newdf = pd.DataFrame(df)
# Out:
# C:\Users\Vivek negi\AppData\Local\Temp\ipykernel_17252\1424105082.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pd.read_sql_query('''SELECT *FROM hrskill''',con=cnx)

# %%
df.head()
# Out:
#    MyUnknownColumn  Candidate Ref DOJ Extended  Duration to accept offer  \
# 0                0        2110407          Yes                        14
# 1                1        2112635           No                        18
# 2                2        2112838           No                         3
# 3                3        2115021           No                        26
# 4                4        2115125          Yes                         1
#
#    Notice period Offered band  Pecent hike expected in CTC  \
# 0             30           E2                       -20.79
# 1             30           E2                        50.00
# 2             45           E2                        42.84
# 3             30           E2                        42.84
# 4            120           E2                        42.59
#
#    Percent hike offered in CTC  Percent difference CTC Joining Bonus  \
# 0                        13.16                   42.86            No
# ...
